# %%
import torch
import torchvision
print("torch :",torch.__version__)
print("torchvision :",torchvision.__version__)
# Out:
# torch : 2.9.0+cu128
# torchvision : 0.24.0+cu128

# %%
from model import model
cnn= model()
cnn.load_weights(path="mnist_cnn.pth")
# Out:
# <All keys matched successfully>

# %%
from model import get_activations
activations= get_activations(cnn)
from model import make_prediction

make_prediction(cnn,input_url="https://conx.readthedocs.io/en/latest/_images/MNIST_44_0.png" )
# Out:
# Predicted class: 0
# /home/kashif/Desktop/arvr/AR-VR/ARVR_env/lib/python3.12/site-packages/PIL/Image.py:1039: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(

# %%
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

# %%
from model import plot_activations
input_tensor=activations["layer_2"] 
plot_activations(input_tensor)
# Out:
# shape of the input torch.Size([28, 28])

# %%
from model import plot_activations
for i in range(3):
    name=f"layer_{i+1}"
    plot_activations(activations[name])
# Out:
# shape of the input torch.Size([28, 28])
# shape of the input torch.Size([28, 28])
# shape of the input torch.Size([14, 14])
